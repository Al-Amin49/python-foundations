# %%
# Practise problems
#1 Take values of length and breadth of a rectangle from user and check if it is square or not.


length=int(input())
breadth=int(input())

if length==breadth:
    print("Square")
else:
    print("Rectangle")
# Out:
# Square

# %%
#2 Take threee integer input from user and print the greatest number.

num1=int(input())
num2=int(input())
num3=int(input())

if num1>num2 and num1>num3:
    print(num1)
elif num2>num1 and num2>num3:
    print(num2)
else:
    print(num3)
# Out:
# 9

# %%
#3 Even or odd
num=int(input())
if num%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
#4 write a program to take integer input from user and display the grade according to the following criera
""" 
>90 - A
>80 and <=90 - B
>=60 and <=80 - C
<60 - D
"""
grade=int(input())

if grade >90:
	print("A")
elif grade >80 and grade <=90:
 print("B")
elif  grade >=60 and grade <=80:
 print("C")
elif grade <60:
    print("D")
# Out:
# D

# %%
# 5
year=int(input())

if (year%400 == 0)  or (year%4 == 0 and year%100 != 0):
    print("Leap year")
else:
    print("Not a leap year")
